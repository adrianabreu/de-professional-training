# %%
# %sql
drop catalog neon;
drop connection my_connection;

# %%
# %sql
CREATE CONNECTION my_connection TYPE postgresql
OPTIONS (
  host 'ep-calm-tree-a209yifr.eu-central-1.aws.neon.tech',
  user '<>',
  password '<>'
);

# %%
# %sql
-- Voy a aprovechar para usar una base de datos de neon que cree hace un tiempo y que es de databricks :) 
CREATE FOREIGN CATALOG IF NOT EXISTS neon USING CONNECTION my_connection
OPTIONS (database 'professordesignation');

# %%
# %sql
-- Como ya hemos filtrado por la base de datos, los schemas son los que están dentro
select * from neon.public.playing_with_neon
